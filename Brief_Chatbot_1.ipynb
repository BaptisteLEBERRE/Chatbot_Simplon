# %% [markdown]
# # Chatbot
#
# Options :

# %%
train_model = True
#train_model = False

# %%
#api = False
api = True

# %% [markdown]
# Importer les modules nécessaires :

# %%
import json
import pandas as pd
from nltk.stem.snowball import FrenchStemmer, EnglishStemmer
from langdetect import detect
import unicodedata

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, Embedding, LSTM , Dense,GlobalMaxPooling1D,Flatten
from tensorflow.keras.models import Model

from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import random
import numpy as np

from keras.models import load_model

from flask import Flask, render_template, request

# %% [markdown]
# Obtenir la DataFrame à partir de ``content.json`` :

# %%
#ouvrir le fichier JSON
with open('content.json') as content:
  data1 = json.load(content)

#créer les listes vides
tags = []
inputs = []
responses={}
#les remplir avec le contenu du JSON
for intent in data1['intents']:
  responses[intent['tag']]=intent['liste_output']
  for lines in intent['liste_input']:
    inputs.append(lines)
    tags.append(intent['tag'])
    
#convertir en DataFrame
data = pd.DataFrame({"inputs":inputs,
                     "tags":tags})

#mélanger aléatoirement
data = data.sample(frac=1)

#montrer la DataFrame
display(data)
#montrer les catégories
data["tags"].value_counts()
# Out:
#                                                 inputs         tags
# 92   Les professeurs sont-ils des experts dans leur...  enseignants
# 19   L’entreprise désire devenir partenaire de la f...   partenaire
# 40                 Quel niveau d’étude doit-on avoir ?    admission
# 56                  Quel est le programme de l’année ?    pédagogie
# 57   Doit-on chercher une entreprise pour l’alterna...   alternance
# ..                                                 ...          ...
# 104                              Comment est-on noté ?  evaluation
# 118                        Que peux-t-on faire après ?    debouches
# 48                        Quand commencent les cours ?         date
# 102                            Est-ce qu’on est noté ?  evaluation
# 35                    Comment rejoindre la formation ?    admission
#
# [124 rows x 2 columns]
# admission          12
# alternance         12
# debouches          12
# salutation          9
# evaluation          9
# fin                 9
# pédagogie           8
# affirmation         6
# aide financiere     6
# apprenant           5
# enseignants         5
# titre               5
# covid               5
# insultes            5
# negation            5
# partenaire          4
# code                4
# date                3
# Name: tags, dtype: int64

# %% [markdown]
# Créer les fonctions de traitement du texte :

# %%
#enlever les accents du texte
def remove_accents(input_str):
    nfkd_form = unicodedata.normalize('NFKD', input_str)
    only_ascii = nfkd_form.encode('ASCII', 'ignore')
    return str(only_ascii)[2:-1]

# %%
#traiter le texte
def treatment(text):
    #vérifier si c'est une question
    if text[-1] == "?":
        question = "?"
    else:
        question = "0"
        
    #vérifier la langue
    if detect(text) == "fr":
        language = "francais"
    elif detect(text) == "en":
        language = "anglais"
    else:
        language = "francais"
    
    #segmenter le texte et traiter chaque mot et chaque lettre
    text = text.split()
    words_list = []
    for word in text:
        letters_list = []
        for character in word:
            #vérifier que le caractère est une lettre
            if character.isalpha():
                #rajouter à la liste en minuscule
                letters_list.append(character.lower())
            else:
                letters_list.append(" ")
        word = "".join(letters_list)
        
        #appliquer le stemming suivant la langue
        for word1 in word.split():
            if language == "fr":
                word1 = EnglishStemmer().stem(word1)
            else:
                word1 = FrenchStemmer().stem(word1)
            #enlever les accents
            word1 = remove_accents(word1)
            words_list.append(word1)
            
    #joindre en une string
    text = " ".join(words_list)
    return " ".join([text, question, language])
    #pour avoir en trois colonnes
    #return [text, question, language]

# %% [markdown]
# Obtenir une colonne avec les inputs traités :

# %%
#pour avoir en trois colonnes

#text_list = []
#ques_list = []
#lang_list = []

#for value in data["inputs"]:
    #value = treatment(value)
    #text_list.append(value[0])
    #ques_list.append(value[1])
    #lang_list.append(value[2])

#data["text"] = text_list
#data["?"] = ques_list
#data["language"] = lang_list

# %%
data["texts"] = data["inputs"].apply(treatment)

# %%
data
# Out:
#                                                 inputs         tags  \
# 92   Les professeurs sont-ils des experts dans leur...  enseignants
# 19   L’entreprise désire devenir partenaire de la f...   partenaire
# 40                 Quel niveau d’étude doit-on avoir ?    admission
# 56                  Quel est le programme de l’année ?    pédagogie
# 57   Doit-on chercher une entreprise pour l’alterna...   alternance
# ..                                                 ...          ...
# 104                              Comment est-on noté ?  evaluation
# 118                        Que peux-t-on faire après ?    debouches
# 48                        Quand commencent les cours ?         date
# 102                            Est-ce qu’on est noté ?  evaluation
# 35                    Comment rejoindre la formation ?    admission
#
#                                                  texts
# 92   le professeur sont il de expert dan leur domai...
# 19   l entrepris desir deven partenair de la format...
# 40         quel niveau d etud doit on avoir ? francais
# 56           quel est le programm de l anne ? francais
# 57   doit on cherch une entrepris pour l altern ? f...
# ..                                                 ...
# 104                      comment est on not ? francais
# 118                que peux t on fair apres ? francais
# 48                 quand commencent le cour ? francais
# 102                    est ce qu on est not ? francais
# 35               comment rejoindr la format ? francais
#
# [124 rows x 3 columns]

# %% [markdown]
# Appliquer le tokenizer sur les inputs traités :

# %%
tokenizer = Tokenizer(num_words=2000)
tokenizer.fit_on_texts(data['texts'])
train = tokenizer.texts_to_sequences(data['texts'])
#apply padding
from tensorflow.keras.preprocessing.sequence import pad_sequences
x_train = pad_sequences(train)

# %% [markdown]
# Appliquer LabelEncoder() sur les tags :

# %%
le = LabelEncoder()
y_train = le.fit_transform(data['tags'])

# %%
input_shape = x_train.shape[1]
print(input_shape)
# Out:
# 18

# %%
vocabulary = len(tokenizer.word_index)
print("Nombre de mots uniques : ",vocabulary)
output_length = le.classes_.shape[0]
print("Taille des outputs : ",output_length)
# Out:
# Nombre de mots uniques :  205
# Taille des outputs :  18

# %% [markdown]
# Créer et entraîner le modèle :

# %%
if train_model == True:
    #créer le modèle
    i = Input(shape=(input_shape,))
    x = Embedding(vocabulary+1,10)(i)
    x = LSTM(10,return_sequences=True)(x)
    x = Flatten()(x)
    x = Dense(output_length,activation="softmax")(x)
    model  = Model(i,x)

    #compiler le modèle
    model.compile(loss="sparse_categorical_crossentropy",optimizer='adam',metrics=['accuracy'])

    #entraîner le modèle
    train = model.fit(x_train,y_train,epochs=200)
    
    #sauvegarder le modèle
    model.save("chatbot.h5")
# Out:
# Epoch 1/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.8896 - accuracy: 0.0645
# Epoch 2/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.8828 - accuracy: 0.0565
# Epoch 3/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.8763 - accuracy: 0.1129
# Epoch 4/200
# 4/4 [==============================] - 0s 10ms/step - loss: 2.8695 - accuracy: 0.1210
# Epoch 5/200
# 4/4 [==============================] - 0s 12ms/step - loss: 2.8604 - accuracy: 0.1048
# Epoch 6/200
# 4/4 [==============================] - 0s 12ms/step - loss: 2.8505 - accuracy: 0.0968
# Epoch 7/200
# 4/4 [==============================] - 0s 11ms/step - loss: 2.8379 - accuracy: 0.0968
# Epoch 8/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.8236 - accuracy: 0.0968
# Epoch 9/200
# 4/4 [==============================] - 0s 11ms/step - loss: 2.8156 - accuracy: 0.0968
# Epoch 10/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.8015 - accuracy: 0.0968
# Epoch 11/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.7916 - accuracy: 0.0968
# Epoch 12/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.7854 - accuracy: 0.0968
# Epoch 13/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.7772 - accuracy: 0.0968
# Epoch 14/200
# 4/4 [==============================] - 0s 9ms/step - loss: 2.7708 - accuracy: 0.1048
# Epoch 15/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7628 - accuracy: 0.1210
# Epoch 16/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.7548 - accuracy: 0.1210
# Epoch 17/200
# 4/4 [==============================] - 0s 8ms/step - loss: 2.7463 - accuracy: 0.1452
# Epoch 18/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.7354 - accuracy: 0.2097
# Epoch 19/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.7244 - accuracy: 0.2500
# Epoch 20/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.7125 - accuracy: 0.2661
# Epoch 21/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6994 - accuracy: 0.2742
# Epoch 22/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6821 - accuracy: 0.3226
# Epoch 23/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6644 - accuracy: 0.3387
# Epoch 24/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6436 - accuracy: 0.3387
# Epoch 25/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.6219 - accuracy: 0.3065
# Epoch 26/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.5968 - accuracy: 0.2984
# Epoch 27/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.5707 - accuracy: 0.2984
# Epoch 28/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.5395 - accuracy: 0.2903
# Epoch 29/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.5105 - accuracy: 0.2903
# Epoch 30/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4785 - accuracy: 0.2823
# Epoch 31/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4444 - accuracy: 0.3065
# Epoch 32/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.4141 - accuracy: 0.3145
# Epoch 33/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.3792 - accuracy: 0.3145
# Epoch 34/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3453 - accuracy: 0.2903
# Epoch 35/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.3115 - accuracy: 0.3145
# Epoch 36/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2802 - accuracy: 0.3065
# Epoch 37/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2455 - accuracy: 0.3145
# Epoch 38/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.2162 - accuracy: 0.3468
# Epoch 39/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1825 - accuracy: 0.3468
# Epoch 40/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.1510 - accuracy: 0.3629
# Epoch 41/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.1162 - accuracy: 0.3952
# Epoch 42/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0835 - accuracy: 0.4113
# Epoch 43/200
# 4/4 [==============================] - 0s 6ms/step - loss: 2.0525 - accuracy: 0.3952
# Epoch 44/200
# 4/4 [==============================] - 0s 7ms/step - loss: 2.0233 - accuracy: 0.4032
# Epoch 45/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9826 - accuracy: 0.4194
# Epoch 46/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.9486 - accuracy: 0.4274
# Epoch 47/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.9177 - accuracy: 0.4194
# Epoch 48/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8794 - accuracy: 0.4435
# Epoch 49/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8432 - accuracy: 0.4677
# Epoch 50/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.8115 - accuracy: 0.4758
# Epoch 51/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.7761 - accuracy: 0.4839
# Epoch 52/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.7400 - accuracy: 0.5000
# Epoch 53/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.7077 - accuracy: 0.5081
# Epoch 54/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6679 - accuracy: 0.5161
# Epoch 55/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.6369 - accuracy: 0.5161
# Epoch 56/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.6108 - accuracy: 0.5161
# Epoch 57/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.5730 - accuracy: 0.5484
# Epoch 58/200
# 4/4 [==============================] - ETA: 0s - loss: 1.8654 - accuracy: 0.34 - 0s 6ms/step - loss: 1.5336 - accuracy: 0.5403
# Epoch 59/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.5008 - accuracy: 0.5484
# Epoch 60/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.4807 - accuracy: 0.5806
# Epoch 61/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4483 - accuracy: 0.5887
# Epoch 62/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.4259 - accuracy: 0.5645
# Epoch 63/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3853 - accuracy: 0.5968
# Epoch 64/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3612 - accuracy: 0.6371
# Epoch 65/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.3275 - accuracy: 0.6290
# Epoch 66/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3078 - accuracy: 0.6452
# Epoch 67/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2788 - accuracy: 0.6613
# Epoch 68/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2570 - accuracy: 0.7016
# Epoch 69/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2314 - accuracy: 0.6290
# Epoch 70/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.2088 - accuracy: 0.6774
# Epoch 71/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1851 - accuracy: 0.6774
# Epoch 72/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1672 - accuracy: 0.6613
# Epoch 73/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.1562 - accuracy: 0.7177
# Epoch 74/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1374 - accuracy: 0.7016
# Epoch 75/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1022 - accuracy: 0.7661
# Epoch 76/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.0949 - accuracy: 0.7500
# Epoch 77/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0652 - accuracy: 0.7500
# Epoch 78/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0511 - accuracy: 0.7823
# Epoch 79/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0265 - accuracy: 0.7016
# Epoch 80/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0095 - accuracy: 0.7419
# Epoch 81/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9940 - accuracy: 0.7823
# Epoch 82/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.9726 - accuracy: 0.8065
# Epoch 83/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9560 - accuracy: 0.7661
# Epoch 84/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9419 - accuracy: 0.7823
# Epoch 85/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9206 - accuracy: 0.8226
# Epoch 86/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9102 - accuracy: 0.7742
# Epoch 87/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9156 - accuracy: 0.8387
# Epoch 88/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8956 - accuracy: 0.8065
# Epoch 89/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8959 - accuracy: 0.8065
# Epoch 90/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8596 - accuracy: 0.8468
# Epoch 91/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8423 - accuracy: 0.8306
# Epoch 92/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8233 - accuracy: 0.8629
# Epoch 93/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8089 - accuracy: 0.8790
# Epoch 94/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7937 - accuracy: 0.8790
# Epoch 95/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7819 - accuracy: 0.8952
# Epoch 96/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7687 - accuracy: 0.9032
# Epoch 97/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7545 - accuracy: 0.9113
# Epoch 98/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.7427 - accuracy: 0.9113
# Epoch 99/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7344 - accuracy: 0.8952
# Epoch 100/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7138 - accuracy: 0.9113
# Epoch 101/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7104 - accuracy: 0.9113
# Epoch 102/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6993 - accuracy: 0.9194
# Epoch 103/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6853 - accuracy: 0.9194
# Epoch 104/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6748 - accuracy: 0.9194
# Epoch 105/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6640 - accuracy: 0.9194
# Epoch 106/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6526 - accuracy: 0.9355
# Epoch 107/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6415 - accuracy: 0.9516
# Epoch 108/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6290 - accuracy: 0.9274
# Epoch 109/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6176 - accuracy: 0.9355
# Epoch 110/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6100 - accuracy: 0.9516
# Epoch 111/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6038 - accuracy: 0.9355
# Epoch 112/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5988 - accuracy: 0.9435
# Epoch 113/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5847 - accuracy: 0.9274
# Epoch 114/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5772 - accuracy: 0.9194
# Epoch 115/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5638 - accuracy: 0.9597
# Epoch 116/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5545 - accuracy: 0.9597
# Epoch 117/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5393 - accuracy: 0.9597
# Epoch 118/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5366 - accuracy: 0.9677
# Epoch 119/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5348 - accuracy: 0.9435
# Epoch 120/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5118 - accuracy: 0.9758
# Epoch 121/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5111 - accuracy: 0.9677
# Epoch 122/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5045 - accuracy: 0.9597
# Epoch 123/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5002 - accuracy: 0.9758
# Epoch 124/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4853 - accuracy: 0.9758
# Epoch 125/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4765 - accuracy: 0.9677
# Epoch 126/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4659 - accuracy: 0.9758
# Epoch 127/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4605 - accuracy: 0.9839
# Epoch 128/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4503 - accuracy: 0.9839
# Epoch 129/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4435 - accuracy: 0.9758
# Epoch 130/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4377 - accuracy: 0.9758
# Epoch 131/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4298 - accuracy: 0.9839
# Epoch 132/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4228 - accuracy: 0.9919
# Epoch 133/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4173 - accuracy: 0.9839
# Epoch 134/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4096 - accuracy: 0.9919
# Epoch 135/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4015 - accuracy: 0.9919
# Epoch 136/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4030 - accuracy: 0.9839
# Epoch 137/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3946 - accuracy: 0.9919
# Epoch 138/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3856 - accuracy: 0.9919
# Epoch 139/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3850 - accuracy: 0.9839
# Epoch 140/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3727 - accuracy: 0.9919
# Epoch 141/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3696 - accuracy: 0.9919
# Epoch 142/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3660 - accuracy: 0.9839
# Epoch 143/200
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3610 - accuracy: 0.9919
# Epoch 144/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3537 - accuracy: 0.9919
# Epoch 145/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3452 - accuracy: 0.9919
# Epoch 146/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3381 - accuracy: 0.9919
# Epoch 147/200
# 4/4 [==============================] - ETA: 0s - loss: 0.3305 - accuracy: 1.00 - 0s 8ms/step - loss: 0.3343 - accuracy: 0.9919
# Epoch 148/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3289 - accuracy: 0.9919
# Epoch 149/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3262 - accuracy: 0.9919
# Epoch 150/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3199 - accuracy: 0.9919
# Epoch 151/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3155 - accuracy: 0.9919
# Epoch 152/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3077 - accuracy: 0.9919
# Epoch 153/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3043 - accuracy: 1.0000
# Epoch 154/200
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2991 - accuracy: 0.9919
# Epoch 155/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2961 - accuracy: 0.9919
# Epoch 156/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2912 - accuracy: 1.0000
# Epoch 157/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2864 - accuracy: 1.0000
# Epoch 158/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2834 - accuracy: 0.9919
# Epoch 159/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2789 - accuracy: 1.0000
# Epoch 160/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2862 - accuracy: 0.9839
# Epoch 161/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2679 - accuracy: 1.0000
# Epoch 162/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2705 - accuracy: 1.0000
# Epoch 163/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2664 - accuracy: 0.9919
# Epoch 164/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2607 - accuracy: 1.0000
# Epoch 165/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2581 - accuracy: 1.0000
# Epoch 166/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2528 - accuracy: 0.9919
# Epoch 167/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2498 - accuracy: 1.0000
# Epoch 168/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2437 - accuracy: 1.0000
# Epoch 169/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2430 - accuracy: 0.9919
# Epoch 170/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2386 - accuracy: 1.0000
# Epoch 171/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2362 - accuracy: 1.0000
# Epoch 172/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2314 - accuracy: 1.0000
# Epoch 173/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2302 - accuracy: 0.9919
# Epoch 174/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2331 - accuracy: 1.0000
# Epoch 175/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2234 - accuracy: 1.0000
# Epoch 176/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2189 - accuracy: 0.9919
# Epoch 177/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2198 - accuracy: 1.0000
# Epoch 178/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2209 - accuracy: 0.9919
# Epoch 179/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2133 - accuracy: 1.0000
# Epoch 180/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2096 - accuracy: 1.0000
# Epoch 181/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2087 - accuracy: 0.9919
# Epoch 182/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2057 - accuracy: 1.0000
# Epoch 183/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2025 - accuracy: 1.0000
# Epoch 184/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1997 - accuracy: 0.9919
# Epoch 185/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1941 - accuracy: 1.0000
# Epoch 186/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1913 - accuracy: 1.0000
# Epoch 187/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1892 - accuracy: 1.0000
# Epoch 188/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1885 - accuracy: 1.0000
# Epoch 189/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1838 - accuracy: 1.0000
# Epoch 190/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1817 - accuracy: 1.0000
# Epoch 191/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1782 - accuracy: 1.0000
# Epoch 192/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1778 - accuracy: 1.0000
# Epoch 193/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1743 - accuracy: 1.0000
# Epoch 194/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1719 - accuracy: 1.0000
# Epoch 195/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1697 - accuracy: 1.0000
# Epoch 196/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1674 - accuracy: 1.0000
# Epoch 197/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1665 - accuracy: 1.0000
# Epoch 198/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1657 - accuracy: 1.0000
# Epoch 199/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1602 - accuracy: 1.0000
# Epoch 200/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1607 - accuracy: 1.0000

# %%
if train_model == True:
    #montrer l'historique de précision et des pertes
    plt.plot(train.history['accuracy'],label="précision de l'entraînement")
    plt.plot(train.history['loss'],label="pertes de l'entraînement")
    plt.legend()

# %%
if train_model == False:
    model = load_model("chatbot.h5")

# %% [markdown]
# ## Test
#
# Taper 0 pour sortir.

# %%
if api == False:
    while True:
      texts_p = []
      prediction_input = input('You : ')
      if prediction_input == "0":
        break

      #removing punctuation and converting to lowercase
      prediction_input = treatment(prediction_input)
      texts_p.append(prediction_input)
      print(prediction_input)

      #tokenizing and padding
      prediction_input = tokenizer.texts_to_sequences(texts_p)
      prediction_input = np.array(prediction_input).reshape(-1)
      prediction_input = pad_sequences([prediction_input],input_shape)
      print(prediction_input)

      #getting output from model
      output = model.predict(prediction_input)
      output = output.argmax()
      print(output)

      #finding the right tag and predicting
      response_tag = le.inverse_transform([output])[0]
      print(response_tag)
      #print("Going Merry : ",random.choice(responses[response_tag]))
      if response_tag == "goodbye":
        break

# %% [markdown]
# ## API

# %%
if api == True:
    app = Flask(__name__)

    s_list = ["inconnu", "apprenant", "partenaire"]
    user_status = s_list[0]

    #créer deux listes de tags identifiant l'utilisateur comme étant apprenant ou partenaire
    appr_list = []
    part_list = []

    #créer deux dictionnaires avec les équivalents d'output apprenant/partenaire
    to_appr = {}
    to_part = {}


    #definir les app.route
    @app.route("/")
    def index():
        return render_template("index.html")

    @app.route("/get")
    #fonction de réponse
    def get_bot_response():
        #obtenir la question et la formatter
        texts_p = []
        prediction_input = request.args.get('msg')
        prediction_input = treatment(prediction_input)
        texts_p.append(prediction_input)

        #formatter l'input
        prediction_input = tokenizer.texts_to_sequences(texts_p)
        prediction_input = np.array(prediction_input).reshape(-1)
        prediction_input = pad_sequences([prediction_input],input_shape)

        #prédire l'output
        output = model.predict(prediction_input)
        output = output.argmax()

        #vérifier si l'output identifie l'utilisateur
        if output in appr_list:
            user_status = s_list[1]
        elif output in part_list:
            user_status = s_list[2]

        #si l'utilisateur est identifié et l'output est susceptible de changer pour ça, alors le changer
        if user_status == s_list[1] and output in to_appr.keys():
            output = to_appr[output]
        elif user_status == s_list[2] and output in to_part.keys():
            output = to_part[output]

        #transformer la réponse et la renvoyer
        response_tag = le.inverse_transform([output])[0]
        response = str("Chatbot : ",random.choice(responses[response_tag]))
        return response

    #lancer l'API
    if __name__ == "__main__":
        app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
